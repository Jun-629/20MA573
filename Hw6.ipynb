# %% [markdown]
# <a href="https://colab.research.google.com/github/Jun-629/20MA573/blob/master/Hw6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt  

def exactbm(T,N):
  w0 = 0
  w_list = [0]
  h = T/N
  wi = 0
  for i in range(N):
    Z = np.random.normal(0,1)
    wi += np.sqrt(h) * Z
    w_list.append(wi)
  return w_list

x0 = [x/10000 for x in range(10001)]
y0 = exactbm(100,10000)
plt.plot(x0,y0)

for t in range(100,111):
  y = w(t,t/0.1)
# Out:
# 0

# %%
for t in range(100,111):
